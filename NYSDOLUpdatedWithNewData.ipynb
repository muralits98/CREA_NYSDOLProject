# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pylab
import glob
import sys
import os

# %%
data1 = pd.read_csv(r"C:\Users\tsmur\Downloads\inscsv (2).csv", skiprows = 6, skipfooter=4, engine='python')
data1.columns = [c.replace(' ', '_') for c in data1.columns]
data1
# Out:
#                                                                                                                                                                  Area_=Capital_Region
# NAICS Code  Industry Title             Year    Quarter  Establishments  Month1 Employment  Month2 Employment  Month3 Employment  Average Employment  Total Wages        Average Wages
# 111        NAICS 111: Crop Production 2019(P) 1        89              500                539                604                548                 $3920334                    $7154
#                                       2018(P) Annual   90              NaN                NaN                NaN                934                 $26338895                  $28200
#                                               1        90              496                495                564                518                 $3682109                    $7108
# ...

# %%
data1 = pd.read_csv(r"C:\Users\tsmur\Downloads\inscsv (2).csv", skiprows = 7)
data1
data1.columns = [c.replace(' ', '_') for c in data1.columns]
data1['_Year'] = data1['_Year'].str.strip(')')
data1['_Year'] = data1['_Year'].str.strip('P')
data1['_Year'] = data1['_Year'].str.strip('(')
data1
# Out:
#     NAICS_Code             _Industry_Title _Year _Quarter  _Establishments  \
# 0          111  NAICS 111: Crop Production  2019        1               89
# 1          111  NAICS 111: Crop Production  2018   Annual               90
# 2          111  NAICS 111: Crop Production  2018        1               90
# 3          111  NAICS 111: Crop Production  2018        2               91
# 4          111  NAICS 111: Crop Production  2018        3               91
# 5          111  NAICS 111: Crop Production  2018        4               89
# 6          111  NAICS 111: Crop Production  2017   Annual               86
# 7          111  NAICS 111: Crop Production  2017        1               85
# 8          111  NAICS 111: Crop Production  2017        2               85
# 9          111  NAICS 111: Crop Production  2017        3               86
# 10         111  NAICS 111: Crop Production  2017        4               86
# ...

# %%
A = ['Annual']
data2 = data1[data1._Quarter.isin(A)]
data3 = data2.sort_values(by='_Year')
data3
plt.size(500)
plt.plot(data3._Year,data3._Average_Employment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-04d02b37a6af> in <module>
#       3 data3 = data2.sort_values(by='_Year')
#       4 data3
# ----> 5 plt.size(500)
#       6 plt.plot(data3._Year,data3._Average_Employment)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'size'

# %%
path = r'C:\Users\tsmur\Desktop\RevStuff\ExcelFiles' # use your path
all_files = glob.glob(path + "\*.csv")

li = []

for filename in all_files:
    data1 = pd.read_csv(filename, skiprows = 6, skipfooter=4, engine='python')
    df = data1.rename(columns=data1.iloc[0])[1:]
#     df = pd.read_csv(filename, index_col=None, header=0)
#     need = data1.rename(columns=data1.iloc[0])[1:]
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame['Industry Title'].unique()
# Out:
# array(['NAICS 111: Crop Production', 'NAICS 112: Animal Production',
#        'NAICS 113: Forestry and Logging',
#        'NAICS 114: Fishing, Hunting and Trapping',
#        'NAICS 115: Agriculture & Forestry Support Activity',
#        'NAICS 311: Food Manufacturing',
#        'NAICS 312: Beverage & Tobacco Product Manufacturing'],
#       dtype=object)

# %%
data = frame[['Industry Title','Year', 'Quarter', 'Average Employment']]
Q = ['Annual']
data[data.Quarter.isin(Q)]
data.columns = [c.replace(' ', '_') for c in data.columns]

# %%
# path = r'C:\Users\tsmur\Desktop\RevStuff\CapitalRegion' # use your path
# all_files = glob.glob(path + "\*.csv")

# li = []

path = r'C:\Users\tsmur\Desktop\RevStuff\CapitalRegion' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f,skiprows = 7) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

frame = pd.concat(li, axis=0)

# %%
pd.write_csv(frame)

# %%
frame.Indsutry

# %%
n = []
A = ['Annual']
for naic in data['Industry_Title'].unique():
    n.append(naic)
    need = data[data.Industry_Title.isin(n) & data.Quarter.isin(A)]
    print("This is for the industry ",n[0])
    print(need)
    plt.scatter(data.Year, data.Average_Employment)
    #plt.bar(data.Year,data.Average_Employment)
    plt.show()
    n=[]

# %%
need

# %%
data1 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (2).csv", skiprows = 7)
data1
data1.columns = [c.replace(' ', '_') for c in data1.columns]
data1['_Year'] = data1['_Year'].str.strip(')')
data1['_Year'] = data1['_Year'].str.strip('P')
data1['_Year'] = data1['_Year'].str.strip('(')
data1
data2 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (1).csv", skiprows = 7)
data2
data2.columns = [c.replace(' ', '_') for c in data2.columns]
data2['_Year'] = data1['_Year'].str.strip(')')
data2['_Year'] = data1['_Year'].str.strip('P')
data2['_Year'] = data1['_Year'].str.strip('(')
data2
#
data3 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (3).csv", skiprows = 7)
data3
data3.columns = [c.replace(' ', '_') for c in data3.columns]
data3['_Year'] = data1['_Year'].str.strip(')')
data3['_Year'] = data1['_Year'].str.strip('P')
data3['_Year'] = data1['_Year'].str.strip('(')
data3
#
data4 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (4).csv", skiprows = 7)
data4.columns = [c.replace(' ', '_') for c in data4.columns]
data4['_Year'] = data1['_Year'].str.strip(')')
data4['_Year'] = data1['_Year'].str.strip('P')
data4['_Year'] = data1['_Year'].str.strip('(')
data4
#
data5 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (5).csv", skiprows = 7)
data5.columns = [c.replace(' ', '_') for c in data5.columns]
data5['_Year'] = data1['_Year'].str.strip(')')
data5['_Year'] = data1['_Year'].str.strip('P')
data5['_Year'] = data1['_Year'].str.strip('(')
data5
#
data6 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv (6).csv", skiprows = 7)
data6.columns = [c.replace(' ', '_') for c in data6.columns]
data6['_Year'] = data1['_Year'].str.strip(')')
data6['_Year'] = data1['_Year'].str.strip('P')
data6['_Year'] = data1['_Year'].str.strip('(')
data6
#
data7 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CapitalRegion\inscsv.csv", skiprows = 7)
data7.columns = [c.replace(' ', '_') for c in data7.columns]
data7['_Year'] = data1['_Year'].str.strip(')')
data7['_Year'] = data1['_Year'].str.strip('P')
data7['_Year'] = data1['_Year'].str.strip('(')
data7
# Out:
#     NAICS_Code             _Industry_Title _Year _Quarter  _Establishments  \
# 0          111  NAICS 111: Crop Production  2019        1               89
# 1          111  NAICS 111: Crop Production  2018   Annual               90
# 2          111  NAICS 111: Crop Production  2018        1               90
# 3          111  NAICS 111: Crop Production  2018        2               91
# 4          111  NAICS 111: Crop Production  2018        3               91
# 5          111  NAICS 111: Crop Production  2018        4               89
# 6          111  NAICS 111: Crop Production  2017   Annual               86
# 7          111  NAICS 111: Crop Production  2017        1               85
# 8          111  NAICS 111: Crop Production  2017        2               85
# 9          111  NAICS 111: Crop Production  2017        3               86
# 10         111  NAICS 111: Crop Production  2017        4               86
# ...

# %%
dcap = pd.concat([data1,data2,data3,data4,data5,data6,data7])

# %%
dcap
# Out:
#     NAICS_Code                  _Industry_Title _Year _Quarter  \
# 0          113  NAICS 113: Forestry and Logging  2019        1
# 1          113  NAICS 113: Forestry and Logging  2018   Annual
# 2          113  NAICS 113: Forestry and Logging  2018        1
# 3          113  NAICS 113: Forestry and Logging  2018        2
# 4          113  NAICS 113: Forestry and Logging  2018        3
# 5          113  NAICS 113: Forestry and Logging  2018        4
# 6          113  NAICS 113: Forestry and Logging  2017   Annual
# 7          113  NAICS 113: Forestry and Logging  2017        1
# 8          113  NAICS 113: Forestry and Logging  2017        2
# 9          113  NAICS 113: Forestry and Logging  2017        3
# 10         113  NAICS 113: Forestry and Logging  2017        4
# 11         113  NAICS 113: Forestry and Logging  2016   Annual
# 12         113  NAICS 113: Forestry and Logging  2016        1
# 13         113  NAICS 113: Forestry and Logging  2016        2
# ...

# %%
dcap._Month1_Employment.unique()
# Out:
# array([  68.,   nan,   65.,   51.,   62.,   73.,   52.,   75.,   63.,
#          53.,   49.,   61.,   50.,   57.,   56.,   45.,   66.,   70.,
#          64.,   67.,   76.,   42.,   54.,   59.,   55.,   60.,   72.,
#          84.,   80.,   98.,   88.,   74.,   95.,   91.,  108.,   90.,
#          92.,   93.,   87.,   83.,   86.,  116.,  100.,  112.,  114.,
#        1351., 1392., 1358., 1403., 1420., 1213., 1341., 1376., 1395.,
#        1244., 1237., 1264., 1285., 1288., 1263., 1306., 1254., 1261.,
#        1310., 1337., 1362., 1277., 1295., 1304., 1292., 1322., 1350.,
#        1353., 1372., 1402., 1399., 1333., 1336., 1378., 1434., 1415.,
#        1360., 1371., 1419., 1393., 1335., 1450., 1414., 1314., 1321.,
#        1344., 1373., 1410., 1391., 1477., 1465., 1416., 1447., 1476.,
#        1440., 1387., 1488., 1483., 1297., 1368., 1230., 1257., 1349.,
#        1299., 1164., 1274., 1215., 1049., 1069., 1161., 1154.,    3.,
# ...

# %%
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = dcap[dcap._Industry_Title.isin(c) & dcap._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
# Out:
# In capital hill region, for the, NAICS 113: Forestry and Logging ,this is the plot and the total for this industry is  1397
# In capital hill region, for the, NAICS 112: Animal Production ,this is the plot and the total for this industry is  25427
# In capital hill region, for the, NAICS 114: Fishing Hunting and Trapping ,this is the plot and the total for this industry is  3
# In capital hill region, for the, NAICS 115: Agriculture & Forestry Support Activity ,this is the plot and the total for this industry is  3306
# In capital hill region, for the, NAICS 311: Food Manufacturing ,this is the plot and the total for this industry is  40107
# In capital hill region, for the, NAICS 312: Beverage & Tobacco Product Manufacturing ,this is the plot and the total for this industry is  11874
# In capital hill region, for the, NAICS 111: Crop Production ,this is the plot and the total for this industry is  12820

# %%
a = ['NAICS 113: Forestry and Logging']
A = ['Annual']
d1 = d[d._Industry_Title.isin(a) & d._Quarter.isin(A) ]
# Out:
#     NAICS_Code                  _Industry_Title _Year _Quarter  \
# 1          113  NAICS 113: Forestry and Logging  2018   Annual
# 6          113  NAICS 113: Forestry and Logging  2017   Annual
# 11         113  NAICS 113: Forestry and Logging  2016   Annual
# 16         113  NAICS 113: Forestry and Logging  2015   Annual
# 21         113  NAICS 113: Forestry and Logging  2014   Annual
# 26         113  NAICS 113: Forestry and Logging  2013   Annual
# 31         113  NAICS 113: Forestry and Logging  2012   Annual
# 36         113  NAICS 113: Forestry and Logging  2011   Annual
# 41         113  NAICS 113: Forestry and Logging  2010   Annual
# 46         113  NAICS 113: Forestry and Logging  2009   Annual
# 51         113  NAICS 113: Forestry and Logging  2008   Annual
# 56         113  NAICS 113: Forestry and Logging  2007   Annual
# 61         113  NAICS 113: Forestry and Logging  2006   Annual
# 66         113  NAICS 113: Forestry and Logging  2005   Annual
# ...

# %%
plt.plot(b,e)
fig = plt.gcf()
fig.set_size_inches(15.5, 7.5)
plt.title("Capital Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
# Out:
# Text(0, 0.5, 'Average Employment')

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (5).csv", skiprows = 7)
data14 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (6).csv", skiprows = 7)
d = pd.concat([data8,data9,data10,data11,data12,data13,data14])

# %%
d.columns = [c.replace(' ', '_') for c in d.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d
# Out:
#     NAICS_Code                                    _Industry_Title _Year  \
# 0          111                         NAICS 111: Crop Production  2019
# 1          111                         NAICS 111: Crop Production  2018
# 2          111                         NAICS 111: Crop Production  2018
# 3          111                         NAICS 111: Crop Production  2018
# 4          111                         NAICS 111: Crop Production  2018
# 5          111                         NAICS 111: Crop Production  2018
# 6          111                         NAICS 111: Crop Production  2017
# 7          111                         NAICS 111: Crop Production  2017
# 8          111                         NAICS 111: Crop Production  2017
# 9          111                         NAICS 111: Crop Production  2017
# 10         111                         NAICS 111: Crop Production  2017
# 11         111                         NAICS 111: Crop Production  2016
# ...

# %%
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = d[d._Industry_Title.isin(c) & d._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
# Out:
# In capital hill region, for the, NAICS 113: Forestry and Logging ,this is the plot and the total for this industry is  1237
# In capital hill region, for the, NAICS 112: Animal Production ,this is the plot and the total for this industry is  20733
# In capital hill region, for the, NAICS 114: Fishing Hunting and Trapping ,this is the plot and the total for this industry is  7
# In capital hill region, for the, NAICS 115: Agriculture & Forestry Support Activity ,this is the plot and the total for this industry is  2202
# In capital hill region, for the, NAICS 311: Food Manufacturing ,this is the plot and the total for this industry is  36565
# In capital hill region, for the, NAICS 312: Beverage & Tobacco Product Manufacturing ,this is the plot and the total for this industry is  17093
# In capital hill region, for the, NAICS 111: Crop Production ,this is the plot and the total for this industry is  14530

# %%
plt.plot(b,e)
fig = plt.gcf()
fig.set_size_inches(20, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
# Out:
# Text(0, 0.5, 'Average Employment')

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (5).csv", skiprows = 7)
data14 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (6).csv", skiprows = 7)
d = pd.concat([data8,data9,data10,data11,data12,data13,data14])
d.columns = [c.replace(' ', '_') for c in d.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d 
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = d[d._Industry_Title.isin(c) & d._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
plt.show()
plt.bar(b,e)
fig = plt.gcf()
fig.set_size_inches(25, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
plt.show()
# Out:
# In capital hill region, for the, NAICS 113: Forestry and Logging ,this is the plot and the total for this industry is  1237
# In capital hill region, for the, NAICS 112: Animal Production ,this is the plot and the total for this industry is  20733
# In capital hill region, for the, NAICS 114: Fishing Hunting and Trapping ,this is the plot and the total for this industry is  7
# In capital hill region, for the, NAICS 115: Agriculture & Forestry Support Activity ,this is the plot and the total for this industry is  2202
# In capital hill region, for the, NAICS 311: Food Manufacturing ,this is the plot and the total for this industry is  36565
# In capital hill region, for the, NAICS 312: Beverage & Tobacco Product Manufacturing ,this is the plot and the total for this industry is  17093
# In capital hill region, for the, NAICS 111: Crop Production ,this is the plot and the total for this industry is  14530

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\FingerLakes\inscsv (5).csv", skiprows = 7)
dFingerLakes = pd.concat([data8,data9,data10,data11,data12,data13,data14])
dFingerLakes.columns = [c.replace(' ', '_') for c in dFingerLakes.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d 
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = dFingerLakes[dFingerLakes._Industry_Title.isin(c) & dFingerLakes._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    c= []
plt.legend()
plt.show()
plt.bar(b,e)
fig = plt.gcf()
fig.set_size_inches(20, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
plt.show()
# Out:
# In capital hill region, for the, NAICS 113: Forestry and Logging ,this is the plot and the total for this industry is  791
# In capital hill region, for the, NAICS 112: Animal Production ,this is the plot and the total for this industry is  44495
# In capital hill region, for the, NAICS 114: Fishing Hunting and Trapping ,this is the plot and the total for this industry is  0
# In capital hill region, for the, NAICS 115: Agriculture & Forestry Support Activity ,this is the plot and the total for this industry is  7679
# In capital hill region, for the, NAICS 311: Food Manufacturing ,this is the plot and the total for this industry is  115755
# In capital hill region, for the, NAICS 312: Beverage & Tobacco Product Manufacturing ,this is the plot and the total for this industry is  52263
# In capital hill region, for the, NAICS 111: Crop Production ,this is the plot and the total for this industry is  63306

# %%
A = 'NAICS 312: Beverage & Tobacco Product Manufacturing'
d3 = d2[d2._Industry_Title.isin(F)]
d2
# Out:
#     NAICS_Code             _Industry_Title    _Year _Quarter  _Establishments  \
# 91         111  NAICS 111: Crop Production     2000   Annual              268
# 86         111  NAICS 111: Crop Production     2001   Annual              264
# 81         111  NAICS 111: Crop Production     2002   Annual              258
# 76         111  NAICS 111: Crop Production     2003   Annual              252
# 71         111  NAICS 111: Crop Production     2004   Annual              252
# 66         111  NAICS 111: Crop Production     2005   Annual              251
# 61         111  NAICS 111: Crop Production     2006   Annual              247
# 56         111  NAICS 111: Crop Production     2007   Annual              253
# 51         111  NAICS 111: Crop Production     2008   Annual              263
# 46         111  NAICS 111: Crop Production     2009   Annual              270
# 41         111  NAICS 111: Crop Production     2010   Annual              278
# ...

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (5).csv", skiprows = 7)
data14 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\HudsonValleyRegion\inscsv (6).csv", skiprows = 7)
d = pd.concat([data8,data9,data10,data11,data12,data13,data14])
d.columns = [c.replace(' ', '_') for c in d.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d 
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = d[d._Industry_Title.isin(c) & d._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In Hudson Valley region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
plt.show()
plt.bar(b,e)
fig = plt.gcf()
fig.set_size_inches(20, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
plt.show()
# Out:
# In Hudson Valley region, for the, NAICS 113: Forestry and Logging ,this is the plot and the total for this industry is  626
# In Hudson Valley region, for the, NAICS 112: Animal Production ,this is the plot and the total for this industry is  12291
# In Hudson Valley region, for the, NAICS 114: Fishing Hunting and Trapping ,this is the plot and the total for this industry is  65
# In Hudson Valley region, for the, NAICS 115: Agriculture & Forestry Support Activity ,this is the plot and the total for this industry is  11356
# In Hudson Valley region, for the, NAICS 311: Food Manufacturing ,this is the plot and the total for this industry is  98705
# In Hudson Valley region, for the, NAICS 312: Beverage & Tobacco Product Manufacturing ,this is the plot and the total for this industry is  16680
# In Hudson Valley region, for the, NAICS 111: Crop Production ,this is the plot and the total for this industry is  37157

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (5).csv", skiprows = 7)
data14 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (6).csv", skiprows = 7)
d = pd.concat([data8,data9,data10,data11,data12,data13,data14])
d.columns = [c.replace(' ', '_') for c in d.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d 
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = d[d._Industry_Title.isin(c) & d._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
plt.show()
plt.plot(b,e)
fig = plt.gcf()
fig.set_size_inches(20, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
plt.show()

# %%
data8 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv.csv", skiprows = 7)
data9 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (1).csv", skiprows = 7)
data10 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (2).csv", skiprows = 7)
data11= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (3).csv", skiprows = 7)
data12 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (4).csv", skiprows = 7)
data13= pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (5).csv", skiprows = 7)
data14 = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\CentralNewYork\inscsv (6).csv", skiprows = 7)
d = pd.concat([data8,data9,data10,data11,data12,data13,data14])
d.columns = [c.replace(' ', '_') for c in d.columns]
d['_Year'] = d['_Year'].str.strip(')')
d['_Year'] = d['_Year'].str.strip('P')
d['_Year'] = d['_Year'].str.strip('(')
d 
A = ['Annual']
b = ['NAICS 113: Forestry and Logging', 'NAICS 112: Animal Production',
       'NAICS 114: Fishing Hunting and Trapping',
       'NAICS 115: Agriculture & Forestry Support Activity',
       'NAICS 311: Food Manufacturing',
       'NAICS 312: Beverage & Tobacco Product Manufacturing',
       'NAICS 111: Crop Production']
c=[]
e=[]
for i in b:
    c.append(i)
    d1 = d[d._Industry_Title.isin(c) & d._Quarter.isin(A) ]
    d2 = d1.sort_values(by='_Year', ascending=True)
    e.append(np.sum(d2._Average_Employment))
    print("In capital hill region, for the,",c[0], ",this is the plot and the total for this industry is ",np.sum(d2._Average_Employment))
    plt.plot(d2._Year,d2._Average_Employment,label = c[0])
    fig = plt.gcf()
    fig.set_size_inches(15.5, 7.5)
    plt.savefig(a[0]+'.png')
    c= []
plt.legend()
plt.show()
plt.plot(b,e)
fig = plt.gcf()
fig.set_size_inches(20, 7.5)
plt.title("New York Region")
plt.xlabel("Industries")
plt.ylabel("Average Employment")
plt.show()
