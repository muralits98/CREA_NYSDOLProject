# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd
import pylab as plt
from pandas import ExcelWriter
from pandas import ExcelFile

# %% [markdown]
# # We realized on 09/27/19 that this dataset did not contain the major manufacturing industries becuase they don't break it down to county level due to legal reasons. We shift to an excel based analysis and save this for the smaller industries.
#
# # Eg. They report collectively for Southern Tier which is not broken down and hence went unrecorded here

# %% [markdown]
# # Importing the Datasets

# %%
"""
Here, s0 to s18 represents the csv files in the folder from years 2000 to 2018. Although we use only till 2017 in the actual code

To change this to your systems file location, Change the entire url until the part where the file name begins
"""
S0 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2000.txt")
S1 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2001.txt")
S2 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2002.txt")
S3 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2003.txt")
S4 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2004.txt")
S5 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2005.txt")
S6 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2006.txt")
S7 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2007.txt")
S8 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2008.txt")
S9 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2009.txt")
S10 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2010.txt")
S11 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2011.txt")
S12 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2012.txt")
S13 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2013.txt")
S14 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2014.txt")
S15 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2015.txt")
S16 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2016.txt")
S17 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2017.txt")
S18 = pd.read_csv(r"C:/Users/tsmur/Box/Center For Regional Economic Advancement/Economic Development Programs/Research/Fall 2019 Research/Data/ag_Economy/qcew/qcew_annual_2018.txt")

# %%
Data1 = S18[S18['AREATYPE'],S18['AREA'],S18['NAICS'],S18['TITLE'],S18['YEAR'],S18['ESTAB'],S18['AVGEMP'],S18['TOTWAGE'],S18['ANNAVGSAL']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-cd160888ddcf> in <module>
# ----> 1 Data1 = S18[S18['AREATYPE'],S18['AREA'],S18['NAICS'],S18['TITLE'],S18['YEAR'],S18['ESTAB'],S18['AVGEMP'],S18['TOTWAGE'],S18['ANNAVGSAL']]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# ...

# %%
"""
Combining the datasets
"""
Data = pd.concat([S0,S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17])

# %% [markdown]
# # Exploratory Data Analysis

# %%
Data
# Out:
#                AREATYPE              AREA  NAICS  \
# 0                 State    New York State      0
# 1                 State    New York State      1
# 2                 State    New York State     11
# 3                 State    New York State    111
# 4                 State    New York State    112
# 5                 State    New York State    113
# 6                 State    New York State    114
# 7                 State    New York State    115
# 8                 State    New York State     21
# 9                 State    New York State    211
# 10                State    New York State    212
# 11                State    New York State    213
# 12                State    New York State     22
# 13                State    New York State    221
# 14                State    New York State     23
# 15                State    New York State    236
# 16                State    New York State    237
# 17                State    New York State    238
# ...

# %%
np.shape(Data)
# Out:
# (196791, 9)

# %%
naics = ['11']
areatype = ['County']
YEAR1 = ['2014']
a = Data[Data.NAICS.isin(naics) & Data.AREATYPE.isin(areatype) & Data.YEAR.isin(YEAR1)]
a
# Out:
#      AREATYPE                 AREA  NAICS  \
# 118    County        Albany County     11
# 227    County      Allegany County     11
# 321    County         Bronx County     11
# 432    County        Broome County     11
# 537    County   Cattaraugus County     11
# 640    County        Cayuga County     11
# 742    County    Chautauqua County     11
# 850    County       Chemung County     11
# 951    County      Chenango County     11
# 1051   County       Clinton County     11
# 1155   County      Columbia County     11
# 1260   County      Cortland County     11
# 1357   County      Delaware County     11
# 1454   County      Dutchess County     11
# 1561   County          Erie County     11
# 1675   County         Essex County     11
# 1771   County      Franklin County     11
# 1864   County        Fulton County     11
# 1959   County       Genesee County     11
# 2060   County        Greene County     11
# 2157   County      Hamilton County     11
# ...

# %%
Data['AREA'].unique()
# Out:
# array(['New York State', 'Albany County', 'Allegany County',
#        'Bronx County', 'Broome County', 'Cattaraugus County',
#        'Cayuga County', 'Chautauqua County', 'Chemung County',
#        'Chenango County', 'Clinton County', 'Columbia County',
#        'Cortland County', 'Delaware County', 'Dutchess County',
#        'Erie County', 'Essex County', 'Franklin County', 'Fulton County',
#        'Genesee County', 'Greene County', 'Hamilton County',
#        'Herkimer County', 'Jefferson County', 'Kings County',
#        'Lewis County', 'Livingston County', 'Madison County',
#        'Monroe County', 'Montgomery County', 'Nassau County',
#        'New York County', 'Niagara County', 'Oneida County',
#        'Onondaga County', 'Ontario County', 'Orange County',
#        'Orleans County', 'Oswego County', 'Otsego County',
#        'Putnam County', 'Queens County', 'Rensselaer County',
#        'Richmond County', 'Rockland County', 'Saratoga County',
# ...

# %%
Data['AREATYPE'].unique()
# Out:
# array(['State', 'County', 'Labor Market Area',
#        'Workforce Investment Region', 'Metropolitan Statistical Area',
#        'Micropolitan Statistical Area', 'Metropolitan Division',
#        'Balance of State'], dtype=object)

# %%
Data['NAICS'].unique()
# Out:
# array([  0,   1,  11, 111, 112, 113, 114, 115,  21, 211, 212, 213,  22,
#        221,  23, 236, 237, 238,  31, 311, 312, 313, 314, 315, 316, 321,
#        322, 323, 324, 325, 326, 327, 331, 332, 333, 334, 335, 336, 337,
#        339,  42, 423, 424, 425,  44, 441, 442, 443, 444, 445, 446, 447,
#        448, 451, 452, 453, 454,  48, 481, 483, 484, 485, 486, 487, 488,
#        491, 492, 493,  51, 511, 512, 515, 516, 517, 518, 519,  52, 522,
#        523, 524, 525,  53, 531, 532, 533,  54, 541,  55, 551,  56, 561,
#        562,  61, 611,  62, 621, 622, 623, 624,  71, 711, 712, 713,  72,
#        721, 722,  81, 811, 812, 813, 814,  92, 921,  95, 951, 952, 953,
#         99, 482], dtype=int64)

# %%
Data['YEAR'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype=int64)

# %%
Data['AREATYPE'].unique()
# Out:
# array(['State', 'County', 'Labor Market Area',
#        'Workforce Investment Region', 'Metropolitan Statistical Area',
#        'Micropolitan Statistical Area', 'Metropolitan Division',
#        'Balance of State'], dtype=object)

# %%
duplicateRowsDF = Data[Data.duplicated(['YEAR'])]
print("Duplicate Rows based on a single column are:", duplicateRowsDF, sep='\n')
# Out:
# Duplicate Rows based on a single column are:
#                AREATYPE              AREA  NAICS  \
# 1                 State    New York State      1
# 2                 State    New York State     11
# 3                 State    New York State    111
# 4                 State    New York State    112
# 5                 State    New York State    113
# 6                 State    New York State    114
# 7                 State    New York State    115
# 8                 State    New York State     21
# 9                 State    New York State    211
# 10                State    New York State    212
# 11                State    New York State    213
# 12                State    New York State     22
# 13                State    New York State    221
# 14                State    New York State     23
# 15                State    New York State    236
# 16                State    New York State    237
# 17                State    New York State    238
# ...

# %% [markdown]
# # Creating a new Dataframe for further analysis

# %%
Clean = Data[['NAICS','AREATYPE', 'AREA', 'YEAR', 'AVGEMP']]

# %% [markdown]
# # Creating the list of years to be analyzed

# %%
years = []
for i in range(2000,2018):
    years.append(i)

# %%
print(years, "\t")
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %% [markdown]
# # Southern Tier Dataset table

# %%
Areatype = ["County"]
Area = ['Tompkins County','Tompkins', 'Tioga County', 'Steuben County', 'Schuyler County','Delaware County','Chenango County','Chemung County','Broome County']
naics = ['112','111','113','114','115','311','312']
SouthernTier = Clean[Clean.YEAR.isin(years) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics)]
SouthernTier
# Out:
#       NAICS AREATYPE             AREA  YEAR  AVGEMP
# 386     112   County    Broome County  2000      66
# 387     113   County    Broome County  2000      65
# 395     311   County    Broome County  2000    1167
# 824     112   County  Chenango County  2000      49
# 825     113   County  Chenango County  2000       9
# 832     311   County  Chenango County  2000     401
# 1154    112   County  Delaware County  2000      83
# 1155    113   County  Delaware County  2000      29
# 4127    312   County  Schuyler County  2000      61
# 4325    111   County   Steuben County  2000     175
# 4326    112   County   Steuben County  2000      98
# 4327    113   County   Steuben County  2000      15
# 4337    311   County   Steuben County  2000     620
# 4338    312   County   Steuben County  2000      77
# 4604    111   County     Tioga County  2000      18
# 4605    112   County     Tioga County  2000      28
# 4613    311   County     Tioga County  2000     170
# ...

# %%
print("For the year 2000, the avg employment in the Southern Tier is",np.sum(SouthernTier['AVGEMP']))
# Out:
# For the year 2000, the avg employment in the Southern Tier is 70868

# %% [markdown]
# # The following analysis are carried over the period 2000 - 2017

# %% [markdown]
# # Important Definitions

# %%
"""
The following are the NAICS codes relevant to each industry
"""

ManufacturingNaics = ['311','312','313','314','315','316','321','322','323','324',
                      '325','326','327','331','332','333','334','335','336','337',
                      '339']
AgriculturalNaics = ['112','111','113','114','115','311','312']
AgroManuNaics = ['311','312']

"""
The following are the counties coming under each area

"""

SouthernTierArea = ['Tompkins County','Tompkins', 'Tioga County', 'Steuben County', 'Schuyler County','Delaware County','Chenango County','Chemung County','Broome County']
FingerLakesArea = ['Genesse County','Genesse', 'Livingston County','Livingston', 'Monroe County','Monroe', 'Ontario County','Ontario', 'Orleans County','Orleans','Seneca County','Seneca','Wayne County','Wayne','Wyoming County','Wyoming','Yates County','Yates']
CentralNYArea = ['Cayuga County','Cayuga', 'Cortland County','Cortland','Madison County','Madison','Onandaga County','Onandaga','Oswego County','Oswego']
GrowNYArea = ['Genesse County','Genesse', 'Livingston County','Livingston', 'Monroe County','Monroe', 'Ontario County','Ontario', 'Orleans County','Orleans','Seneca County','Seneca','Wayne County','Wayne','Wyoming County','Wyoming','Yates County','Yates', 'Tompkins County','Tompkins', 'Tioga County','Tioga', 'Steuben County','Steuben', 'Schuyler County','Schuyler','Delaware County','Delaware','Chenango County','Chenango','Chemung County','Chemung','Broome County','Broome']
WesternNYArea = ['Allegany County','Allegany','Cattaraugus County','Cattaraugus','Chautauqua County','Chautauqua','Niagara County','Niagara']
MidHudsonArea = ['Dutchess County','Dutchess', 'Orange County','Orange','orange','orange County','Putnam County','Putnam','Rockland County','Rockland','Sullivan County','Sullivan','Ulster County','Ulster','Westchester County','Westchester']
MohawkValleyArea = ['Fulton County','Fulton','Herkimer County','Herkimer','Montgomery County','Montgomery','Oneida County','Oneida','Otsego County','Otsego','Schoharie County','Schoharie']
NorthCountryArea = ['Clinton County','Clinton','Essex County','Essex','Franklin County','Franklin','Hamilton County','Hamilton','Jefferson County','Jefferson','Lewis County','Lewis','St. Lawrence County']
CapitalArea = ['Albany County','Albany','Columbia County','Columbia','Greene County','Greene','Saratoga County','Saratoga','Schenectady County','Schenectady','Rensselaer County','Warren County','Warren','Washington County','Washington']
LongIslandArea = ['Nassau County','Suffolk County','Nassau','Suffolk']

NYStateArea = ['New York State']

# %% [markdown]
# # Southern Tier Region

# %%
"""
This is for the Southern Tier Region in Upstate NY.  Agricultural NAICS

"""
YEars = []
sum0 = []
sum5 = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(SouthernTierArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Southern Tier region is",np.sum(SouthernTier['AVGEMP']))
    sum0.append(np.sum(SouthernTier['AVGEMP']))
    naics1 = ['0']
    Allindustries = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics1)]
    print("For the year " + str(YEars[0]) + ", the avg employment for total industries in the Southern Tier Region is",np.sum(Allindustries['AVGEMP']))
    sum5.append(np.sum(Allindustries['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum0)
fig2 = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Southern Tier region is 3842
# For the year 2000, the avg employment for total industries in the Southern Tier Region is 279845
# For the year 2001, the avg employment in the Southern Tier region is 3896
# For the year 2001, the avg employment for total industries in the Southern Tier Region is 280242
# For the year 2002, the avg employment in the Southern Tier region is 3861
# For the year 2002, the avg employment for total industries in the Southern Tier Region is 273014
# For the year 2003, the avg employment in the Southern Tier region is 3843
# For the year 2003, the avg employment for total industries in the Southern Tier Region is 268363
# For the year 2004, the avg employment in the Southern Tier region is 3840
# For the year 2004, the avg employment for total industries in the Southern Tier Region is 268430
# For the year 2005, the avg employment in the Southern Tier region is 3523
# ...

# %% [markdown]
# # Finger Lakes Region

# %%
"""
This is for the Finger Lakes Region.  Agricultural NAICS
"""
sum1 = []
sum5 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    FingerLakes = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(FingerLakesArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Finger Lakes region is",np.sum(FingerLakes['AVGEMP']))
    sum1.append(np.sum(FingerLakes['AVGEMP']))
    naics1 = ['0']
    Allindustries = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics1)]
    print("For the year " + str(YEars[0]) + ", the avg employment for total industries in the Finger Lakes Region is",np.sum(Allindustries['AVGEMP']))
    sum5.append(np.sum(Allindustries['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum1)
fig2 = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Finger Lakes region is 10581
# For the year 2000, the avg employment for total industries in the Finger Lakes Region is 279845
# For the year 2001, the avg employment in the Finger Lakes region is 10470
# For the year 2001, the avg employment for total industries in the Finger Lakes Region is 280242
# For the year 2002, the avg employment in the Finger Lakes region is 10556
# For the year 2002, the avg employment for total industries in the Finger Lakes Region is 273014
# For the year 2003, the avg employment in the Finger Lakes region is 10749
# For the year 2003, the avg employment for total industries in the Finger Lakes Region is 268363
# For the year 2004, the avg employment in the Finger Lakes region is 11397
# For the year 2004, the avg employment for total industries in the Finger Lakes Region is 268430
# For the year 2005, the avg employment in the Finger Lakes region is 10470
# ...

# %% [markdown]
# # Central New York Region

# %%
"""
This is for the Central New York Region.  Agricultural NAICS
"""
sum2 = []
sum5 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    CentralNewYork = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Central New York region is",np.sum(CentralNewYork['AVGEMP']))
    sum2.append(np.sum(CentralNewYork['AVGEMP']))
    naics = ['0']
    Allindustries = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics)]
    print("For the year " + str(YEars[0]) + ", the avg employment for total industries in the Central New York Region is",np.sum(Allindustries['AVGEMP']))
    sum5.append(np.sum(Allindustries['AVGEMP'])/np.sum(CentralNewYork['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum2)
fig2 = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Central New York region is 2414
# For the year 2000, the avg employment for total industries in the Central New York Region is 279845
# For the year 2001, the avg employment in the Central New York region is 2352
# For the year 2001, the avg employment for total industries in the Central New York Region is 280242
# For the year 2002, the avg employment in the Central New York region is 2360
# For the year 2002, the avg employment for total industries in the Central New York Region is 273014
# For the year 2003, the avg employment in the Central New York region is 2301
# For the year 2003, the avg employment for total industries in the Central New York Region is 268363
# For the year 2004, the avg employment in the Central New York region is 2017
# For the year 2004, the avg employment for total industries in the Central New York Region is 268430
# For the year 2005, the avg employment in the Central New York region is 1998
# ...

# %% [markdown]
# # Grow New York Region

# %%
"""
This is for the Grow New York Region.  Agricultural NAICS

"""
sum4 = []
sum5 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    GrowNY = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(GrowNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Grow New York region is",np.sum(GrowNY['AVGEMP']))
    sum4.append(np.sum(GrowNY['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum4)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Grow New York region is 14423
# For the year 2001, the avg employment in the Grow New York region is 14366
# For the year 2002, the avg employment in the Grow New York region is 14417
# For the year 2003, the avg employment in the Grow New York region is 14592
# For the year 2004, the avg employment in the Grow New York region is 15237
# For the year 2005, the avg employment in the Grow New York region is 13993
# For the year 2006, the avg employment in the Grow New York region is 14458
# For the year 2007, the avg employment in the Grow New York region is 14846
# For the year 2008, the avg employment in the Grow New York region is 15452
# For the year 2009, the avg employment in the Grow New York region is 15443
# For the year 2010, the avg employment in the Grow New York region is 15488
# For the year 2011, the avg employment in the Grow New York region is 15792
# ...

# %% [markdown]
# # New York State Region

# %%
"""
This is for the New York State Region. Agricultural NAICS

"""
sum = []
YEars = []
Areatype = ["State"]
for i in years:
    YEars.append(i)
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NYStateArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the New York State region is",np.sum(NYState['AVGEMP']))
    sum.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the New York State region is 83243
# For the year 2001, the avg employment in the New York State region is 83421
# For the year 2002, the avg employment in the New York State region is 81781
# For the year 2003, the avg employment in the New York State region is 81486
# For the year 2004, the avg employment in the New York State region is 80401
# For the year 2005, the avg employment in the New York State region is 79022
# For the year 2006, the avg employment in the New York State region is 78611
# For the year 2007, the avg employment in the New York State region is 79294
# For the year 2008, the avg employment in the New York State region is 78819
# For the year 2009, the avg employment in the New York State region is 77182
# For the year 2010, the avg employment in the New York State region is 78076
# For the year 2011, the avg employment in the New York State region is 78921
# ...

# %% [markdown]
#  # Western New York Region

# %%
"""
This is for the Western New York Region. Agricultural NAICS

"""
sum5 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ['County']
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(WesternNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Western New York region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Western New York region is 5652
# For the year 2001, the avg employment in the Western New York region is 5805
# For the year 2002, the avg employment in the Western New York region is 5577
# For the year 2003, the avg employment in the Western New York region is 5204
# For the year 2004, the avg employment in the Western New York region is 5203
# For the year 2005, the avg employment in the Western New York region is 5061
# For the year 2006, the avg employment in the Western New York region is 4969
# For the year 2007, the avg employment in the Western New York region is 5157
# For the year 2008, the avg employment in the Western New York region is 5188
# For the year 2009, the avg employment in the Western New York region is 5152
# For the year 2010, the avg employment in the Western New York region is 5060
# For the year 2011, the avg employment in the Western New York region is 5150
# ...

# %%
"""
This is for the Mid-Hudson New York Region. Agricultural NAICS

"""
sum5 = []
YEars = []
Areatype = ["County"]
for i in years:
    YEars.append(i)
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MidHudsonArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Mid-Hudson region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Mid-Hudson region is 8317
# For the year 2001, the avg employment in the Mid-Hudson region is 8113
# For the year 2002, the avg employment in the Mid-Hudson region is 7934
# For the year 2003, the avg employment in the Mid-Hudson region is 8005
# For the year 2004, the avg employment in the Mid-Hudson region is 8185
# For the year 2005, the avg employment in the Mid-Hudson region is 8090
# For the year 2006, the avg employment in the Mid-Hudson region is 8445
# For the year 2007, the avg employment in the Mid-Hudson region is 8438
# For the year 2008, the avg employment in the Mid-Hudson region is 8477
# For the year 2009, the avg employment in the Mid-Hudson region is 8476
# For the year 2010, the avg employment in the Mid-Hudson region is 8811
# For the year 2011, the avg employment in the Mid-Hudson region is 8719
# For the year 2012, the avg employment in the Mid-Hudson region is 9008
# ...

# %%
"""
This is for the Mohawk Valley Region. Agricultural NAICS

"""
sum5 = []
YEars = []
Areatype = ['County']
for i in years:
    YEars.append(i)
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MohawkValleyArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Mohawk Valley region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Mohawk Valley region is 2780
# For the year 2001, the avg employment in the Mohawk Valley region is 2662
# For the year 2002, the avg employment in the Mohawk Valley region is 2690
# For the year 2003, the avg employment in the Mohawk Valley region is 2691
# For the year 2004, the avg employment in the Mohawk Valley region is 2723
# For the year 2005, the avg employment in the Mohawk Valley region is 2732
# For the year 2006, the avg employment in the Mohawk Valley region is 2814
# For the year 2007, the avg employment in the Mohawk Valley region is 2941
# For the year 2008, the avg employment in the Mohawk Valley region is 3055
# For the year 2009, the avg employment in the Mohawk Valley region is 3060
# For the year 2010, the avg employment in the Mohawk Valley region is 3188
# For the year 2011, the avg employment in the Mohawk Valley region is 3265
# For the year 2012, the avg employment in the Mohawk Valley region is 3299
# ...

# %%
"""
This is for the North Country Region. Agricultural NAICS

"""
sum5 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NorthCountryArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the North Country region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the North Country region is 2074
# For the year 2001, the avg employment in the North Country region is 2477
# For the year 2002, the avg employment in the North Country region is 2447
# For the year 2003, the avg employment in the North Country region is 2389
# For the year 2004, the avg employment in the North Country region is 2430
# For the year 2005, the avg employment in the North Country region is 2495
# For the year 2006, the avg employment in the North Country region is 2422
# For the year 2007, the avg employment in the North Country region is 2498
# For the year 2008, the avg employment in the North Country region is 2557
# For the year 2009, the avg employment in the North Country region is 2514
# For the year 2010, the avg employment in the North Country region is 2596
# For the year 2011, the avg employment in the North Country region is 2784
# For the year 2012, the avg employment in the North Country region is 2904
# ...

# %%
"""
This is for the Capital Region. Agricultural NAICS

"""
sum5 = []
YEars = []
Areatype = ["County"]
for i in years:
    YEars.append(i)
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CapitalArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Capital region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Capital region is 4143
# For the year 2001, the avg employment in the Capital region is 4244
# For the year 2002, the avg employment in the Capital region is 4148
# For the year 2003, the avg employment in the Capital region is 4217
# For the year 2004, the avg employment in the Capital region is 4354
# For the year 2005, the avg employment in the Capital region is 4150
# For the year 2006, the avg employment in the Capital region is 4116
# For the year 2007, the avg employment in the Capital region is 3984
# For the year 2008, the avg employment in the Capital region is 4115
# For the year 2009, the avg employment in the Capital region is 4087
# For the year 2010, the avg employment in the Capital region is 4083
# For the year 2011, the avg employment in the Capital region is 4080
# For the year 2012, the avg employment in the Capital region is 4157
# For the year 2013, the avg employment in the Capital region is 4309
# ...

# %%
"""
This is for the Long Island Region. Agricultural NAICS

"""
sum5 = []
YEars = []
Areatype = ["County"]
for i in years:
    YEars.append(i)
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(LongIslandArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Long Island region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    YEars = []
fig = plt.plot(years,sum5)
plt.xlabel("Years")
plt.ylabel("Average Employment")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Long Island region is 9817
# For the year 2001, the avg employment in the Long Island region is 9991
# For the year 2002, the avg employment in the Long Island region is 9982
# For the year 2003, the avg employment in the Long Island region is 10002
# For the year 2004, the avg employment in the Long Island region is 10268
# For the year 2005, the avg employment in the Long Island region is 9959
# For the year 2006, the avg employment in the Long Island region is 9610
# For the year 2007, the avg employment in the Long Island region is 9608
# For the year 2008, the avg employment in the Long Island region is 9324
# For the year 2009, the avg employment in the Long Island region is 8806
# For the year 2010, the avg employment in the Long Island region is 9020
# For the year 2011, the avg employment in the Long Island region is 8883
# For the year 2012, the avg employment in the Long Island region is 9354
# ...

# %% [markdown]
# # Percentage of average emplyment on the Grow New York Region vs the Average employment in the New York State Region

# %%
"""
This is the percentage of average emplyment on the Grow New York Region vs the Average employment in the New York State Region.
It is calculated through the years and graphed.

"""
sum4 = []
sum5 = []
sum6 = []
YEars = []
for i in years:
    YEars.append(i)
    Areatype = ["County"]
    Area = ['Genesse County','Genesse', 'Livingston County','Livingston', 'Monroe County','Monroe', 'Ontario County','Ontario', 'Orleans County','Orleans','Seneca County','Seneca','Wayne County','Wayne','Wyoming County','Wyoming','Yates County','Yates', 'Tompkins County','Tompkins', 'Tioga County','Tioga', 'Steuben County','Steuben', 'Schuyler County','Schuyler','Delaware County','Delaware','Chenango County','Chenango','Chemung County','Chemung','Broome County','Broome']
    naics = ['112','111','113','114','115','311','312']
    GrowNY = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Grow New York region is",np.sum(GrowNY['AVGEMP']))
    sum4.append(np.sum(GrowNY['AVGEMP']))
    Areatype = ["State"]
    Area = ["New York State"]
    NYState = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(Area) & Clean.NAICS.isin(naics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the New York State region is",np.sum(NYState['AVGEMP']))
    sum5.append(np.sum(NYState['AVGEMP']))
    sum6.append((np.sum(GrowNY['AVGEMP'])/np.sum(NYState['AVGEMP']))*100)
    YEars = []
plt.plot(years,sum6)
plt.xlabel("Year")
plt.ylabel("Percentage Avg Emp. of GNY to NYState")
plt.xlim(2000,2017,1)
# Out:
# For the year 2000, the avg employment in the Grow New York region is 14423
# For the year 2000, the avg employment in the New York State region is 83243
# For the year 2001, the avg employment in the Grow New York region is 14366
# For the year 2001, the avg employment in the New York State region is 83421
# For the year 2002, the avg employment in the Grow New York region is 14417
# For the year 2002, the avg employment in the New York State region is 81781
# For the year 2003, the avg employment in the Grow New York region is 14592
# For the year 2003, the avg employment in the New York State region is 81486
# For the year 2004, the avg employment in the Grow New York region is 15237
# For the year 2004, the avg employment in the New York State region is 80401
# For the year 2005, the avg employment in the Grow New York region is 13993
# For the year 2005, the avg employment in the New York State region is 79022
# ...

# %% [markdown]
# # Now, looking at all the Manufacturing Industries in each of the areas

# %%
"""
This code 
"""
YEars = []
sum0 = []
sum1= []
sum2= []
sum3= []
sum4= []
sum5= []
sum6= []
sum7= []
sum8= []

Areatype = ["County"]
for i in years:
    YEars.append(i)
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(SouthernTierArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Southern Tier region is",np.sum(SouthernTier['AVGEMP']))
    sum0.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(FingerLakesArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the FingerLakes Area region is",np.sum(SouthernTier['AVGEMP']))
    sum1.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(GrowNYArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the GrowNY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum2.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Central NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum3.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(WesternNYArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Western NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum4.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MidHudsonArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MidHudson Area region is",np.sum(SouthernTier['AVGEMP']))
    sum5.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MohawkValleyArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MohawkValley Area region is",np.sum(SouthernTier['AVGEMP']))
    sum6.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NorthCountryArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the North Country Area region is",np.sum(SouthernTier['AVGEMP']))
    sum7.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CapitalArea) & Clean.NAICS.isin(ManufacturingNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Capital Area region is",np.sum(SouthernTier['AVGEMP']))
    sum8.append(np.sum(SouthernTier['AVGEMP']))
    YEars = []
# Out:
# For the year 2000, the avg employment in the Southern Tier region is 39412
# For the year 2000, the avg employment in the FingerLakes Area region is 99176
# For the year 2000, the avg employment in the GrowNY Area region is 138588
# For the year 2000, the avg employment in the Central NY Area region is 13037
# For the year 2000, the avg employment in the Western NY Area region is 30859
# For the year 2000, the avg employment in the MidHudson Area region is 62513
# For the year 2000, the avg employment in the MohawkValley Area region is 23803
# For the year 2000, the avg employment in the North Country Area region is 12370
# For the year 2000, the avg employment in the Capital Area region is 25368
# For the year 2001, the avg employment in the Southern Tier region is 38483
# For the year 2001, the avg employment in the FingerLakes Area region is 93308
# For the year 2001, the avg employment in the GrowNY Area region is 131791
# ...

# %%
fig1 = plt.plot(years,sum0,label = 'Souther Tier')
fig2 = plt.plot(years,sum1,label = 'Finger Lakes')
fig3 = plt.plot(years,sum2,label = 'Grow NY')
fig4 = plt.plot(years,sum3,label = 'Central NY')
fig5 = plt.plot(years,sum4,label = 'Western NY')
fig6 = plt.plot(years,sum5,label = 'Mid Hudson')
fig7 = plt.plot(years,sum6,label = 'Mohawk Valley')
fig8 = plt.plot(years,sum7,label = 'North Country')
fig9 = plt.plot(years,sum8,label = 'Capital Area')

plt.xlabel("Year")
plt.ylabel("Avg Emp. in the manufacturing industry")
plt.xlim(2000,2017,1)
plt.legend(bbox_to_anchor=(1.1, 1.05))
#plt.savefig('fig1.png')

# %% [markdown]
# # Now, looking at all the Agricultural Industries in each of the areas

# %%
"""
This code 
"""
YEars = []
sum0 = []
sum1= []
sum2= []
sum3= []
sum4= []
sum5= []
sum6= []
sum7= []
sum8= []

Areatype = ["County"]
for i in years:
    YEars.append(i)
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(SouthernTierArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Southern Tier region is",np.sum(SouthernTier['AVGEMP']))
    sum0.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(FingerLakesArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the FingerLakes Area region is",np.sum(SouthernTier['AVGEMP']))
    sum1.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(GrowNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the GrowNY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum2.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Central NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum3.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(WesternNYArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Western NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum4.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MidHudsonArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MidHudson Area region is",np.sum(SouthernTier['AVGEMP']))
    sum5.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MohawkValleyArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MohawkValley Area region is",np.sum(SouthernTier['AVGEMP']))
    sum6.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NorthCountryArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the North Country Area region is",np.sum(SouthernTier['AVGEMP']))
    sum7.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CapitalArea) & Clean.NAICS.isin(AgriculturalNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Capital Area region is",np.sum(SouthernTier['AVGEMP']))
    sum8.append(np.sum(SouthernTier['AVGEMP']))
    YEars = []
# Out:
# For the year 2000, the avg employment in the Southern Tier region is 3842
# For the year 2000, the avg employment in the FingerLakes Area region is 10581
# For the year 2000, the avg employment in the GrowNY Area region is 14423
# For the year 2000, the avg employment in the Central NY Area region is 2414
# For the year 2000, the avg employment in the Western NY Area region is 5652
# For the year 2000, the avg employment in the MidHudson Area region is 8317
# For the year 2000, the avg employment in the MohawkValley Area region is 2780
# For the year 2000, the avg employment in the North Country Area region is 2074
# For the year 2000, the avg employment in the Capital Area region is 4143
# For the year 2001, the avg employment in the Southern Tier region is 3896
# For the year 2001, the avg employment in the FingerLakes Area region is 10470
# For the year 2001, the avg employment in the GrowNY Area region is 14366
# ...

# %%
fig1 = plt.plot(years,sum0,label = 'Souther Tier')
fig2 = plt.plot(years,sum1,label = 'Finger Lakes')
fig3 = plt.plot(years,sum2,label = 'Grow NY')
fig4 = plt.plot(years,sum3,label = 'Central NY')
fig5 = plt.plot(years,sum4,label = 'Western NY')
fig6 = plt.plot(years,sum5,label = 'Mid Hudson')
fig7 = plt.plot(years,sum6,label = 'Mohawk Valley')
fig8 = plt.plot(years,sum7,label = 'North Country')
fig9 = plt.plot(years,sum8,label = 'Capital Area')

plt.xlabel("Year")
plt.ylabel("Avg Emp. in the Agri industry")
plt.xlim(2000,2017,1)
plt.legend(bbox_to_anchor=(1.1, 1.05))
#plt.savefig('fig1.png')

# %%
"""
This code 
"""
YEars = []
sum0 = []
sum1= []
sum2= []
sum3= []
sum4= []
sum5= []
sum6= []
sum7= []
sum8= []

Areatype = ["County"]
for i in years:
    YEars.append(i)
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(SouthernTierArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Southern Tier region is",np.sum(SouthernTier['AVGEMP']))
    sum0.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(FingerLakesArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the FingerLakes Area region is",np.sum(SouthernTier['AVGEMP']))
    sum1.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(GrowNYArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the GrowNY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum2.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Central NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum3.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(WesternNYArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Western NY Area region is",np.sum(SouthernTier['AVGEMP']))
    sum4.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MidHudsonArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MidHudson Area region is",np.sum(SouthernTier['AVGEMP']))
    sum5.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MohawkValleyArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the MohawkValley Area region is",np.sum(SouthernTier['AVGEMP']))
    sum6.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NorthCountryArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the North Country Area region is",np.sum(SouthernTier['AVGEMP']))
    sum7.append(np.sum(SouthernTier['AVGEMP']))
    SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CapitalArea) & Clean.NAICS.isin(AgroManuNaics)]
    print("For the year " + str(YEars[0]) + ", the avg employment in the Capital Area region is",np.sum(SouthernTier['AVGEMP']))
    sum8.append(np.sum(SouthernTier['AVGEMP']))
    YEars = []
# Out:
# For the year 2000, the avg employment in the Southern Tier region is 2630
# For the year 2000, the avg employment in the FingerLakes Area region is 6329
# For the year 2000, the avg employment in the GrowNY Area region is 8959
# For the year 2000, the avg employment in the Central NY Area region is 1299
# For the year 2000, the avg employment in the Western NY Area region is 4292
# For the year 2000, the avg employment in the MidHudson Area region is 5319
# For the year 2000, the avg employment in the MohawkValley Area region is 2022
# For the year 2000, the avg employment in the North Country Area region is 723
# For the year 2000, the avg employment in the Capital Area region is 2316
# For the year 2001, the avg employment in the Southern Tier region is 2650
# For the year 2001, the avg employment in the FingerLakes Area region is 6251
# For the year 2001, the avg employment in the GrowNY Area region is 8901
# ...

# %%
fig1 = plt.plot(years,sum0,label = 'Souther Tier')
fig2 = plt.plot(years,sum1,label = 'Finger Lakes')
fig3 = plt.plot(years,sum2,label = 'Grow NY')
fig4 = plt.plot(years,sum3,label = 'Central NY')
fig5 = plt.plot(years,sum4,label = 'Western NY')
fig6 = plt.plot(years,sum5,label = 'Mid Hudson')
fig7 = plt.plot(years,sum6,label = 'Mohawk Valley')
fig8 = plt.plot(years,sum7,label = 'North Country')
fig9 = plt.plot(years,sum8,label = 'Capital Area')

plt.xlabel("Year")
plt.ylabel("Avg Emp. in the 311,312 Agro Manu industry")
plt.xlim(2000,2017,1)
plt.legend(bbox_to_anchor=(1.1, 1.05))
#plt.savefig('fig1.png')

# %%
"""
This code attempts to calculate the contribution of the individual manufacturing NAICS evey year in the different areas.

"""

YEars = []
sum0 = []
sum1= []
sum2= []
sum3= []
sum4= []
sum5= []
sum6= []
sum7= []
sum8= []
AgroManuNaics = []
Areatype = ["County"]
years = ['2016']
for i in years:
    YEars.append(i)
    for j in ManufacturingNaics:
        AgroManuNaics.append(j)
        print("For the Industry",AgroManuNaics[0])
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(SouthernTierArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the Southern Tier region is",np.sum(SouthernTier['AVGEMP']))
        sum0.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(FingerLakesArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the FingerLakes Area region is",np.sum(SouthernTier['AVGEMP']))
        sum1.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(GrowNYArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the GrowNY Area region is",np.sum(SouthernTier['AVGEMP']))
        sum2.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the Central NY Area region is",np.sum(SouthernTier['AVGEMP']))
        sum3.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(WesternNYArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the Western NY Area region is",np.sum(SouthernTier['AVGEMP']))
        sum4.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MidHudsonArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the MidHudson Area region is",np.sum(SouthernTier['AVGEMP']))
        sum5.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(MohawkValleyArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the MohawkValley Area region is",np.sum(SouthernTier['AVGEMP']))
        sum6.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(NorthCountryArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the North Country Area region is",np.sum(SouthernTier['AVGEMP']))
        sum7.append(np.sum(SouthernTier['AVGEMP']))
        SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CapitalArea) & Clean.NAICS.isin(AgroManuNaics)]
        print("For the year " + str(YEars[0]) + ", the avg employment in the Capital Area region is",np.sum(SouthernTier['AVGEMP']))
        sum8.append(np.sum(SouthernTier['AVGEMP']))
        AgroManuNaics=[]
    YEars = []
# Out:
# For the Industry 311
# For the year 2016, the avg employment in the Southern Tier region is 1997
# For the year 2016, the avg employment in the FingerLakes Area region is 5932
# For the year 2016, the avg employment in the GrowNY Area region is 7929
# For the year 2016, the avg employment in the Central NY Area region is 704
# For the year 2016, the avg employment in the Western NY Area region is 2499
# For the year 2016, the avg employment in the MidHudson Area region is 6267
# For the year 2016, the avg employment in the MohawkValley Area region is 2567
# For the year 2016, the avg employment in the North Country Area region is 576
# For the year 2016, the avg employment in the Capital Area region is 2211
# For the Industry 312
# For the year 2016, the avg employment in the Southern Tier region is 532
# For the year 2016, the avg employment in the FingerLakes Area region is 2235
# For the year 2016, the avg employment in the GrowNY Area region is 2767
# ...

# %%
plt.plot(ManufacturingNaics, sum0, ManufacturingNaics, sum1, ManufacturingNaics, sum2, ManufacturingNaics, sum3,ManufacturingNaics, sum4, ManufacturingNaics, sum5, ManufacturingNaics, sum6, ManufacturingNaics, sum7,ManufacturingNaics, sum8 )

# %%
a = ['312']
YEars = ['2017']
SouthernTier = Clean[Clean.YEAR.isin(YEars) & Clean.AREATYPE.isin(Areatype) & Clean.AREA.isin(CentralNYArea) & Clean.NAICS.isin(a)]
SouthernTier
# Out:
#       NAICS AREATYPE            AREA  YEAR  AVGEMP
# 567     312   County   Cayuga County  2017      39
# 2228    312   County  Madison County  2017      53
# 3260    312   County   Oswego County  2017      15

# %%
c = pd.read_csv(r"C:\Users\tsmur\Desktop\RevStuff\ASM_2016_31GS101_with_ann.csv")
c.head()
# Out:
#                        GEO.id GEO.id2     GEO.display-label         NAICS.id  \
# 0  Geographic identifier code     Id2  Geographic area name  2012 NAICS code
# 1                   0100000US     NaN         United States            31-33
# 2                   0100000US     NaN         United States            31-33
# 3                   0100000US     NaN         United States              311
# 4                   0100000US     NaN         United States              311
#
#           NAICS.display-label YEAR.id                  EMP  \
# 0  Meaning of 2012 NAICS code    Year  Number of employees
# 1               Manufacturing    2016             11112764
# 2               Manufacturing    2015             11168264
# 3          Food manufacturing    2016              1417046
# 4          Food manufacturing    2015              1390907
#
#                                                EMP_S                   PAYANN  \
# ...

# %%
c = pd.read_csv(r"C:\Users\tsmur\Downloads\insCSV123.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-26-86100d4c50b9> in <module>
# ----> 1 c = pd.read_csv(r"C:\Users\tsmur\Downloads\insCSV123.csv")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
